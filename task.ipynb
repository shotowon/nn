# %%
import pandas as pd

dataset = pd.read_csv('IMDB Dataset.csv')
df = dataset
positive = df[df["sentiment"] == "positive"].head(50)
negative = df[df["sentiment"] == "negative"].head(50)
df = pd.concat([positive, negative], ignore_index=True)

testing = dataset.drop(positive.index.union(negative.index))
print(f"000TRAINING000:\n{df}\n\n")
print(f"000TESTING000:\n{testing}")
# Out:
# 000TRAINING000:
#                                                review sentiment
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Petter Mattei's "Love in the Time of Money" is...  positive
# 4   Probably my all-time favorite movie, a story o...  positive
# ..                                                ...       ...
# 95  Oh God, I must have seen this when I was only ...  negative
# 96  "Fate" leads Walter Sparrow to come in possess...  negative
# 97  We brought this film as a joke for a friend, a...  negative
# 98  This was probably the worst movie i have ever ...  negative
# 99  This is a typical Steele novel production in t...  negative
#
# [100 rows x 2 columns]
#
#
# 000TESTING000:
#                                                   review sentiment
# 87     Oh noes one of these attack of the Japanese gh...  negative
# 88     Nicholas Walker is Paul, the local town Revera...  negative
# 89     Hollywood movie industry is the laziest one in...  negative
# 91     If you came here, it's because you've already ...  negative
# 94     I watched this series out of curiosity,wanting...  negative
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [49900 rows x 2 columns]

# %%
df["sentiment_label"] = df["sentiment"].map({"positive": 1, "negative": 0})
df
# Out:
#                                                review sentiment  \
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Petter Mattei's "Love in the Time of Money" is...  positive
# 4   Probably my all-time favorite movie, a story o...  positive
# ..                                                ...       ...
# 95  Oh God, I must have seen this when I was only ...  negative
# 96  "Fate" leads Walter Sparrow to come in possess...  negative
# 97  We brought this film as a joke for a friend, a...  negative
# 98  This was probably the worst movie i have ever ...  negative
# 99  This is a typical Steele novel production in t...  negative
#
#     sentiment_label
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 95                0
# 96                0
# 97                0
# 98                0
# 99                0
#
# [100 rows x 3 columns]

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('opinion_lexicon')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

def preprocess_text(text: str) -> tuple[str, int]:
    text = text.lower()

    tokens = nltk.word_tokenize(text=text)

    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token.isalpha() and token not in stop_words]

    lemmatizer = nltk.WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    cleaned_text = " ".join(tokens)
    return cleaned_text, len(tokens)

df[["clean_review", "num_tokens"]] = pd.DataFrame(
    df["review"].apply(preprocess_text).to_list(),
    index=df.index,
)

df
# Out:
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     /home/shoto/nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /home/shoto/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/shoto/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/shoto/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/shoto/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                                review sentiment  \
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Petter Mattei's "Love in the Time of Money" is...  positive
# 4   Probably my all-time favorite movie, a story o...  positive
# ..                                                ...       ...
# 95  Oh God, I must have seen this when I was only ...  negative
# 96  "Fate" leads Walter Sparrow to come in possess...  negative
# 97  We brought this film as a joke for a friend, a...  negative
# 98  This was probably the worst movie i have ever ...  negative
# 99  This is a typical Steele novel production in t...  negative
#
#     sentiment_label                                       clean_review  \
# 0                 1  one reviewer mentioned watching oz episode hoo...
# 1                 1  wonderful little production br br filming tech...
# 2                 1  thought wonderful way spend time hot summer we...
# 3                 1  petter mattei love time money visually stunnin...
# 4                 1  probably favorite movie story selflessness sac...
# ..              ...                                                ...
# 95                0  oh god must seen twelve ask may young stupid a...
# 96                0  fate lead walter sparrow come possession myste...
# 97                0  brought film joke friend could worst joke play...
# 98                0  probably worst movie ever seen life stupid plo...
# 99                0  typical steele novel production two people und...
#
#     num_tokens
# 0          168
# 1           86
# 2           84
# 3          127
# 4           52
# ..         ...
# 95         136
# 96         218
# 97          35
# 98          66
# 99         146
#
# [100 rows x 5 columns]

# %%
from nltk.corpus import opinion_lexicon

positive_words = opinion_lexicon.positive()
negative_words = opinion_lexicon.negative()

print(f"Lexicon with {len(positive_words)} positive and {len(negative_words)} negative words")
# Out:
# Lexicon with 2006 positive and 4783 negative words

# %%
def count_pos_neg(text: str) -> pd.Series:
    words = text.split()
    nwords = [w for w in words if w in negative_words]
    pwords = [w for w in words if w in positive_words]
    return pd.Series({
        "pwords": pwords,
        "nwords": nwords,
        "pwords_count": len(pwords),
        "nwords_count": len(nwords),
    })

df[["pwords", "nwords", "pwords_count", "nwords_count"]] = df["clean_review"].apply(count_pos_neg)

# %%
df
# Out:
#                                                review sentiment  \
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Petter Mattei's "Love in the Time of Money" is...  positive
# 4   Probably my all-time favorite movie, a story o...  positive
# ..                                                ...       ...
# 95  Oh God, I must have seen this when I was only ...  negative
# 96  "Fate" leads Walter Sparrow to come in possess...  negative
# 97  We brought this film as a joke for a friend, a...  negative
# 98  This was probably the worst movie i have ever ...  negative
# 99  This is a typical Steele novel production in t...  negative
#
#     sentiment_label                                       clean_review  \
# 0                 1  one reviewer mentioned watching oz episode hoo...
# 1                 1  wonderful little production br br filming tech...
# 2                 1  thought wonderful way spend time hot summer we...
# 3                 1  petter mattei love time money visually stunnin...
# 4                 1  probably favorite movie story selflessness sac...
# ..              ...                                                ...
# 95                0  oh god must seen twelve ask may young stupid a...
# 96                0  fate lead walter sparrow come possession myste...
# 97                0  brought film joke friend could worst joke play...
# 98                0  probably worst movie ever seen life stupid plo...
# 99                0  typical steele novel production two people und...
#
#     num_tokens                                             pwords  \
# 0          168  [right, right, trust, regard, classic, appeal,...
# 1           86  [wonderful, comforting, well, seamless, well, ...
# 2           84  [wonderful, hot, witty, likable, well, impress...
# 3          127  [love, stunning, vivid, success, stylishly, so...
# 4           52  [favorite, noble, delight, like, fun, believable]
# ..         ...                                                ...
# 95         136  [impressive, better, convincing, ambitious, be...
# 96         218  [lead, intriguing, pretty, like, good, pretty,...
# 97          35                                                 []
# 98          66                                  [good, hot, like]
# 99         146  [decent, good, excellent, gentle, convincing, ...
#
#                                                nwords  pwords_count  \
# 0   [struck, brutality, faint, timid, punch, priso...            13
# 1                                          [terribly]            11
# 2   [plot, simplistic, killer, disappointed, risk,...            11
# 3                             [loneliness, anxiously]            15
# 4                   [boring, midget, slow, startling]             6
# ..                                                ...           ...
# 95  [stupid, bad, nasty, gross, silly, shark, dang...             7
# 96  [mysterious, fiction, undone, weak, failed, di...            16
# 97  [joke, worst, joke, dire, worst, substandard, ...             0
# 98  [worst, stupid, plot, ridiculous, bad, sick, t...             3
# 99  [tragedy, plot, lost, nasty, accuses, fall, pl...            13
#
#     nwords_count
# 0             20
# 1              1
# 2              6
# 3              2
# 4              4
# ..           ...
# 95            15
# 96            29
# 97            12
# 98             9
# 99            13
#
# [100 rows x 9 columns]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.hidden = nn.Linear(2, 2)
        self.output = nn.Linear(2, 1)

    
    def forward(self, x):
        x = F.relu(self.hidden(x))
        x = F.sigmoid(self.output(x))
        return x

model = MLP()
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
X = df[['pwords_count', 'nwords_count']].values
Y = df['sentiment_label'].values

X = torch.tensor(X, dtype=torch.float32)
Y = torch.tensor(Y, dtype=torch.float32).unsqueeze(1)

# %%
def train_model(model, criterion, optimizer, X, Y, epochs=10000):
    for epoch in range(epochs):
        output = model(X)
        loss = criterion(output, Y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (epoch + 1) % int(epochs / 10) == 0:
            print(f'Epoch {epoch + 1}/{epochs}, Loss: {loss.item():.4f}')

train_model(model, criterion, optimizer, X, Y)
# Out:
# Epoch 1000/10000, Loss: 0.5380
# Epoch 2000/10000, Loss: 0.5299
# Epoch 3000/10000, Loss: 0.5263
# Epoch 4000/10000, Loss: 0.5247
# Epoch 5000/10000, Loss: 0.5232
# Epoch 6000/10000, Loss: 0.5217
# Epoch 7000/10000, Loss: 0.5204
# Epoch 8000/10000, Loss: 0.5192
# Epoch 9000/10000, Loss: 0.5181
# Epoch 10000/10000, Loss: 0.5173

# %%
testing = testing.head(100)
testing["sentiment_label"] = testing["sentiment"].map({"positive": 1, "negative": 0})

testing[["clean_review","num_tokens"]] = pd.DataFrame(
    testing["review"].apply(preprocess_text).to_list(),
    index=testing.index
)

# %%
testing
# Out:
#                                                 review sentiment  \
# 87   Oh noes one of these attack of the Japanese gh...  negative
# 88   Nicholas Walker is Paul, the local town Revera...  negative
# 89   Hollywood movie industry is the laziest one in...  negative
# 91   If you came here, it's because you've already ...  negative
# 94   I watched this series out of curiosity,wanting...  negative
# ..                                                 ...       ...
# 195  Phantasm ....Class. Phantasm II.....awesome. P...  negative
# 196  Ludicrous. Angelic 9-year-old Annakin turns in...  negative
# 197  Scotty (Grant Cramer, who would go on to star ...  negative
# 198  If you keep rigid historical perspective out o...  positive
# 199  The film quickly gets to a major chase scene w...  negative
#
#      sentiment_label                                       clean_review  \
# 87                 0  oh no one attack japanese ghost girl movie eve...
# 88                 0  nicholas walker paul local town reverand marri...
# 89                 0  hollywood movie industry laziest one entire wo...
# 91                 0  came already seen film curious others say br b...
# 94                 0  watched series curiosity wanting see could pos...
# ..               ...                                                ...
# 195                0  phantasm class phantasm ii awesome phantasm ii...
# 196                0  ludicrous angelic annakin turn whiny brat anna...
# 197                0  scotty grant cramer would go star great killer...
# 198                1  keep rigid historical perspective film actuall...
# 199                0  film quickly get major chase scene ever increa...
#
#      num_tokens
# 87           65
# 88          110
# 89          194
# 91           81
# 94           72
# ..          ...
# 195          97
# 196         107
# 197          95
# 198         262
# 199          65
#
# [100 rows x 5 columns]

# %%
testing[["pwords", "nwords", "pwords_count", "nwords_count"]] = testing["clean_review"].apply(count_pos_neg)

# %%
testing
# Out:
#                                                 review sentiment  \
# 87   Oh noes one of these attack of the Japanese gh...  negative
# 88   Nicholas Walker is Paul, the local town Revera...  negative
# 89   Hollywood movie industry is the laziest one in...  negative
# 91   If you came here, it's because you've already ...  negative
# 94   I watched this series out of curiosity,wanting...  negative
# ..                                                 ...       ...
# 195  Phantasm ....Class. Phantasm II.....awesome. P...  negative
# 196  Ludicrous. Angelic 9-year-old Annakin turns in...  negative
# 197  Scotty (Grant Cramer, who would go on to star ...  negative
# 198  If you keep rigid historical perspective out o...  positive
# 199  The film quickly gets to a major chase scene w...  negative
#
#      sentiment_label                                       clean_review  \
# 87                 0  oh no one attack japanese ghost girl movie eve...
# 88                 0  nicholas walker paul local town reverand marri...
# 89                 0  hollywood movie industry laziest one entire wo...
# 91                 0  came already seen film curious others say br b...
# 94                 0  watched series curiosity wanting see could pos...
# ..               ...                                                ...
# 195                0  phantasm class phantasm ii awesome phantasm ii...
# 196                0  ludicrous angelic annakin turn whiny brat anna...
# 197                0  scotty grant cramer would go star great killer...
# 198                1  keep rigid historical perspective film actuall...
# 199                0  film quickly get major chase scene ever increa...
#
#      num_tokens                                             pwords  \
# 87           65                                                 []
# 88          110                         [good, pretty, good, like]
# 89          194  [fine, like, good, nice, glad, good, like, eas...
# 91           81                       [cure, like, good, positive]
# 94           72  [modern, classic, correct, spectacular, blockb...
# ..          ...                                                ...
# 195          97                  [awesome, love, work, good, like]
# 196         107  [angelic, appealing, hero, precious, like, fan...
# 197          95         [great, good, likable, lead, well, pretty]
# 198         262  [entertaining, lead, enjoy, work, prominence, ...
# 199          65                   [like, enjoy, coherent, popular]
#
#                                                 nwords  pwords_count  \
# 87              [attack, scary, sucked, lacked, worse]             0
# 88   [womanizer, fake, death, crazy, misery, sad, w...             4
# 89   [crap, worst, dark, pointless, grudge, bad, sc...             8
# 91   [bleeding, stupid, ripoff, stupid, distraction...             4
# 94                        [burning, drowning, trouble]             6
# ..                                                 ...           ...
# 195  [bad, pointless, crack, funny, dead, zombie, h...             5
# 196  [ludicrous, whiny, brat, bad, crazy, die, ridi...            12
# 197  [killer, bad, bad, bad, bad, limited, fat, fat...             6
# 198  [rigid, fiction, hard, unresolved, quandary, j...            19
# 199                     [destruction, bad, plot, plot]             4
#
#      nwords_count
# 87              5
# 88             12
# 89             25
# 91              7
# 94              3
# ..            ...
# 195            11
# 196            13
# 197             9
# 198            13
# 199             4
#
# [100 rows x 9 columns]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

X_t = testing[['pwords_count', 'nwords_count']].values
Y_t = testing['sentiment_label'].values

X_t = torch.tensor(X_t, dtype=torch.float32)
Y_t = torch.tensor(Y_t, dtype=torch.float32).unsqueeze(1)

model.eval()
with torch.no_grad():
    Y_pred = model(X)

for i, pred in enumerate(Y_pred):
    print(f"predicted {round(float(pred))} actual {int(Y_t[i])}")

y_true = Y_t.numpy().flatten()
y_pred = torch.round(Y_pred).numpy().flatten()

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec = recall_score(y_true, y_pred, zero_division=0)
f1 = f1_score(y_true, y_pred, zero_division=0)
cm = confusion_matrix(y_true, y_pred)

print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1 Score:  {f1:.4f}")
print("\nConfusion Matrix:")
print(cm)
# Out:
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 1 actual 1
# predicted 1 actual 1
# predicted 1 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 1 actual 1
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 1 actual 0
# predicted 1 actual 1
# predicted 1 actual 0
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 1 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 1 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 1 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# Accuracy:  0.5200
# Precision: 0.3243
# Recall:    0.3429
# F1 Score:  0.3333
#
# Confusion Matrix:
# [[40 25]
#  [23 12]]

# %%
model2 = MLP()
criterion2 = nn.BCEWithLogitsLoss()
optimizer2 = torch.optim.Adam(model2.parameters(), lr=0.001)

train_model(model2, criterion2, optimizer2, X, Y, epochs=100000)
# Out:
# Epoch 10000/100000, Loss: 0.6162
# Epoch 20000/100000, Loss: 0.6130
# Epoch 30000/100000, Loss: 0.6130
# Epoch 40000/100000, Loss: 0.6130
# Epoch 50000/100000, Loss: 0.6130
# Epoch 60000/100000, Loss: 0.6130
# Epoch 70000/100000, Loss: 0.6130
# Epoch 80000/100000, Loss: 0.6130
# Epoch 90000/100000, Loss: 0.6130
# Epoch 100000/100000, Loss: 0.6130

# %%
model2.eval()
with torch.no_grad():
    Y_pred = model2(X_t)

for i, pred in enumerate(Y_pred):
    print(f"predicted {round(float(pred))} actual {int(Y_t[i])}")

y_true = Y_t.numpy().flatten()
y_pred = torch.round(Y_pred).numpy().flatten()

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec = recall_score(y_true, y_pred, zero_division=0)
f1 = f1_score(y_true, y_pred, zero_division=0)
cm = confusion_matrix(y_true, y_pred)

print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1 Score:  {f1:.4f}")
print("\nConfusion Matrix:")
print(cm)
# Out:
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 0 actual 1
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 1 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 1 actual 0
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# Accuracy:  0.7700
# Precision: 0.7727
# Recall:    0.4857
# F1 Score:  0.5965
#
# Confusion Matrix:
# [[60  5]
#  [18 17]]

# %%
model3 = MLP()
criterion3 = nn.BCEWithLogitsLoss()
optimizer3 = torch.optim.SGD(model3.parameters(), lr=0.001)

train_model(model3, criterion3, optimizer3, X, Y)

model3.eval()
with torch.no_grad():
    Y_pred = model3(X_t)

for i, pred in enumerate(Y_pred):
    print(f"predicted {round(float(pred))} actual {int(Y_t[i])}")

y_true = Y_t.numpy().flatten()
y_pred = torch.round(Y_pred).numpy().flatten()

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec = recall_score(y_true, y_pred, zero_division=0)
f1 = f1_score(y_true, y_pred, zero_division=0)
cm = confusion_matrix(y_true, y_pred)

print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1 Score:  {f1:.4f}")
print("\nConfusion Matrix:")
print(cm)
# Out:
# Epoch 1000/10000, Loss: 0.7337
# Epoch 2000/10000, Loss: 0.7255
# Epoch 3000/10000, Loss: 0.6926
# Epoch 4000/10000, Loss: 0.6754
# Epoch 5000/10000, Loss: 0.6678
# Epoch 6000/10000, Loss: 0.6645
# Epoch 7000/10000, Loss: 0.6625
# Epoch 8000/10000, Loss: 0.6612
# Epoch 9000/10000, Loss: 0.6601
# Epoch 10000/10000, Loss: 0.6593
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 1 actual 1
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 0 actual 1
# predicted 1 actual 1
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 0
# predicted 0 actual 1
# predicted 0 actual 0
# Accuracy:  0.7200
# Precision: 0.8889
# Recall:    0.2286
# F1 Score:  0.3636
#
# Confusion Matrix:
# [[64  1]
#  [27  8]]

# %%
model3.eval()
with torch.no_grad():
    Y_pred = model3(X_t)

y_true = Y_t.numpy().flatten()
y_pred = torch.round(Y_pred).numpy().flatten()

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec = recall_score(y_true, y_pred, zero_division=0)
f1 = f1_score(y_true, y_pred, zero_division=0)
cm = confusion_matrix(y_true, y_pred)

print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1 Score:  {f1:.4f}")
print("\nConfusion Matrix:")
print(cm)
# Out:
# Accuracy:  0.7200
# Precision: 0.8889
# Recall:    0.2286
# F1 Score:  0.3636
#
# Confusion Matrix:
# [[64  1]
#  [27  8]]
